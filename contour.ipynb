# %% [markdown]
# <a href="https://colab.research.google.com/github/nischayverma0940/hackathon/blob/main/contour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Construct the direct download URL
file_id = '1IdpnJ1Gc7yJZgUWnSuoqRZ9Mi9LEHSbF'
download_url = f'https://drive.google.com/uc?export=download&id={file_id}'

# Load the data from the constructed URL
data = pd.read_csv(download_url)

# %%
import matplotlib.pyplot as plt

# Extract the coordinates
x = data.iloc[:, 2]
y = data.iloc[:, 3]

# Create a scatter plot of the points
plt.figure(figsize=(10, 8))
plt.scatter(x, y, s=10, color='blue')
plt.title('Shape from Given Points')
plt.xlabel('X Coordinates')
plt.ylabel('Y Coordinates')
plt.grid(True)
plt.show()
